# %%
import pandas as pd
import numpy as np
from pysentimiento import create_analyzer
from sklearn.model_selection import train_test_split, ParameterGrid
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression

# %%
dfo = pd.read_csv('data/obama_cleaned.csv')
dfr = pd.read_csv('data/romney_cleaned.csv')
df = pd.concat([dfo, dfr], ignore_index = True)
df.info()
pd.set_option('display.max_rows', None)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11271 entries, 0 to 11270
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tweets  11271 non-null  object
#  1   class   11271 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 176.2+ KB

# %%
df = df.astype({'tweets' : 'string'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11271 entries, 0 to 11270
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tweets  11271 non-null  string
#  1   class   11271 non-null  int64
# dtypes: int64(1), string(1)
# memory usage: 176.2 KB

# %% [markdown]
# # Pre-trained model: BERTweet

# %%
analyzer = create_analyzer(task="sentiment", lang="en")

# %%
def get_prob_dictionary(p):
    start_index = p.find("{") + 1
    end_index = p.rfind("}")
    d = p[start_index:end_index]
    scores = d.split(', ')
    probs = dict()
    for i in range(0, len(scores)):
        k, v = scores[i].split(': ')
        probs[k] = float(v)
    return probs

# %%
pos = list()
neg = list()
neu = list()

for t in df['tweets']:
    p = get_prob_dictionary(str(analyzer.predict(t)))
    pos.append(p['POS'])
    neg.append(p['NEG'])
    neu.append(p['NEU'])


df['pos'] = pos
df['neg'] = neg
df['neu'] = neu

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11271 entries, 0 to 11270
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tweets  11271 non-null  string
#  1   class   11271 non-null  int64
#  2   pos     11271 non-null  float64
#  3   neg     11271 non-null  float64
#  4   neu     11271 non-null  float64
# dtypes: float64(3), int64(1), string(1)
# memory usage: 440.4 KB

# %% [markdown]
# # Predict label using maximum probability

# %%
preds = list()
for idx, row in df.iterrows():
    if row['pos'] >= row['neu'] and row['pos'] >= row['neg']:
        preds.append(1)
    elif row['neg'] >= row['neu'] and row['neg'] > row['pos']:
        preds.append(-1)
    elif row['neu'] > row['pos'] and row['neu'] > row['neg']:
        preds.append(0)
df['pred'] = preds

# %%
acc = accuracy_score(df['class'], df['pred'])
prec = precision_score(df['class'], df['pred'], average = None, zero_division = np.nan)
rec = recall_score(df['class'], df['pred'], average = None)
f1 = f1_score(df['class'], df['pred'], average = None)
print("Accuracy:", acc)
print("Precision:", prec)
print("Recall:", rec)
print("F1:", f1)
# Out:
# Accuracy: 0.6247005589566144
# Precision: [0.68694362 0.51322085 0.68081761]
# Recall: [0.76213992 0.55728739 0.47167756]
# F1: [0.72259071 0.53434714 0.55727156]

# %% [markdown]
# # Predict label using ML models

# %%
def test_model(model, parameters, X, y, n_splits):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state = 27)
    avg_accuracies = list()
    avg_precisions = list()
    avg_recalls = list()
    avg_f1s = list()
    confs = list()
    for conf in ParameterGrid(parameters):
        print('Testing', conf)
        accuracies = list()
        precisions = list()
        recalls = list()
        f1s = list()
        i = 1
        for train_index, test_index in kf.split(X):
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train, y_test = y.iloc[train_index], y.iloc[test_index]
            try:
                model.set_params(**conf)
                model.fit(X_train, y_train)
            except:
                print('Skipped', conf)
                break
            print('\tFold', i, 'of', n_splits)
            y_pred = model.predict(X_test)
            accuracies.append(accuracy_score(y_test, y_pred))
            precisions.append(precision_score(y_test, y_pred, average=None, zero_division = np.nan))
            recalls.append(recall_score(y_test, y_pred, average=None, zero_division = np.nan))
            f1s.append(f1_score(y_test, y_pred, average=None, zero_division = np.nan))
            if i == 1:
                confs.append(conf)
            i = i + 1
            
    
        if len(accuracies) != 0:  
            avg_accuracies.append(sum(accuracies)/len(accuracies))
            avg_precisions.append((sum(precisions)/len(precisions)) if len(precisions) > 0 else np.nan)
            avg_recalls.append(sum(recalls)/len(recalls) if len(recalls) > 0 else np.nan)
            avg_f1s.append(sum(f1s)/len(f1s) if len(f1s) > 0 else np.nan)
        
    results = {'Parameters' : confs,
              'Accuracy' : avg_accuracies,
              'Precision' : avg_precisions,
              'Recall' : avg_recalls,
              'F1' : avg_f1s}
    
    return pd.DataFrame.from_dict(results), model.classes_

# %%
X = df[['pos', 'neg', 'neu']]
y = df['class']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
y.value_counts()
# Out:
# -1    4860
#  0    3657
#  1    2754
# Name: class, dtype: int64

# %%
params_svm = {'C' : (0.1, 1, 10, 100),
             'kernel' : ('rbf', 'poly', 'linear'),
             'degree' : (3, 5, 7),
             'gamma' : ('scale', 'auto')}
svm = SVC()
svm_results, cl_svm = test_model(svm, params_svm, X_train, y_train, 4)
# Out:
# Testing {'C': 0.1, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 3, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 5, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 5, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 5, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 5, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 7, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 7, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 7, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 7, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 7, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 7, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 5, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 5, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 5, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 5, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 7, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 7, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 7, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 7, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 7, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 7, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 3, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 5, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 5, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 5, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 5, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 7, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 7, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 7, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 7, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 7, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 7, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 3, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 5, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 5, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 5, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 5, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 7, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 7, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 7, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 7, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 7, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 7, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4

# %%
svm_results
# Out:
#                                            Parameters  Accuracy  \
# 0   {'C': 0.1, 'degree': 3, 'gamma': 'scale', 'ker...  0.631877
# 1   {'C': 0.1, 'degree': 3, 'gamma': 'scale', 'ker...  0.634428
# 2   {'C': 0.1, 'degree': 3, 'gamma': 'scale', 'ker...  0.626664
# 3   {'C': 0.1, 'degree': 3, 'gamma': 'auto', 'kern...  0.629104
# 4   {'C': 0.1, 'degree': 3, 'gamma': 'auto', 'kern...  0.614241
# 5   {'C': 0.1, 'degree': 3, 'gamma': 'auto', 'kern...  0.626664
# 6   {'C': 0.1, 'degree': 5, 'gamma': 'scale', 'ker...  0.631877
# 7   {'C': 0.1, 'degree': 5, 'gamma': 'scale', 'ker...  0.632320
# 8   {'C': 0.1, 'degree': 5, 'gamma': 'scale', 'ker...  0.626664
# 9   {'C': 0.1, 'degree': 5, 'gamma': 'auto', 'kern...  0.629104
# 10  {'C': 0.1, 'degree': 5, 'gamma': 'auto', 'kern...  0.430790
# 11  {'C': 0.1, 'degree': 5, 'gamma': 'auto', 'kern...  0.626664
# 12  {'C': 0.1, 'degree': 7, 'gamma': 'scale', 'ker...  0.631877
# 13  {'C': 0.1, 'degree': 7, 'gamma': 'scale', 'ker...  0.633540
# 14  {'C': 0.1, 'degree': 7, 'gamma': 'scale', 'ker...  0.626664
# 15  {'C': 0.1, 'degree': 7, 'gamma': 'auto', 'kern...  0.629104
# 16  {'C': 0.1, 'degree': 7, 'gamma': 'auto', 'kern...  0.430790
# 17  {'C': 0.1, 'degree': 7, 'gamma': 'auto', 'kern...  0.626664
# 18  {'C': 1, 'degree': 3, 'gamma': 'scale', 'kerne...  0.632320
# 19  {'C': 1, 'degree': 3, 'gamma': 'scale', 'kerne...  0.635204
# 20  {'C': 1, 'degree': 3, 'gamma': 'scale', 'kerne...  0.627107
# 21  {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel...  0.630546
# 22  {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel...  0.626775
# 23  {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel...  0.627107
# 24  {'C': 1, 'degree': 5, 'gamma': 'scale', 'kerne...  0.632320
# 25  {'C': 1, 'degree': 5, 'gamma': 'scale', 'kerne...  0.632986
# 26  {'C': 1, 'degree': 5, 'gamma': 'scale', 'kerne...  0.627107
# 27  {'C': 1, 'degree': 5, 'gamma': 'auto', 'kernel...  0.630546
# 28  {'C': 1, 'degree': 5, 'gamma': 'auto', 'kernel...  0.595053
# 29  {'C': 1, 'degree': 5, 'gamma': 'auto', 'kernel...  0.627107
# 30  {'C': 1, 'degree': 7, 'gamma': 'scale', 'kerne...  0.632320
# 31  {'C': 1, 'degree': 7, 'gamma': 'scale', 'kerne...  0.633651
# 32  {'C': 1, 'degree': 7, 'gamma': 'scale', 'kerne...  0.627107
# 33  {'C': 1, 'degree': 7, 'gamma': 'auto', 'kernel...  0.630546
# 34  {'C': 1, 'degree': 7, 'gamma': 'auto', 'kernel...  0.430790
# 35  {'C': 1, 'degree': 7, 'gamma': 'auto', 'kernel...  0.627107
# 36  {'C': 10, 'degree': 3, 'gamma': 'scale', 'kern...  0.632653
# 37  {'C': 10, 'degree': 3, 'gamma': 'scale', 'kern...  0.636424
# 38  {'C': 10, 'degree': 3, 'gamma': 'scale', 'kern...  0.626996
# 39  {'C': 10, 'degree': 3, 'gamma': 'auto', 'kerne...  0.633762
# 40  {'C': 10, 'degree': 3, 'gamma': 'auto', 'kerne...  0.633319
# 41  {'C': 10, 'degree': 3, 'gamma': 'auto', 'kerne...  0.626996
# 42  {'C': 10, 'degree': 5, 'gamma': 'scale', 'kern...  0.632653
# 43  {'C': 10, 'degree': 5, 'gamma': 'scale', 'kern...  0.632986
# 44  {'C': 10, 'degree': 5, 'gamma': 'scale', 'kern...  0.626996
# 45  {'C': 10, 'degree': 5, 'gamma': 'auto', 'kerne...  0.633762
# 46  {'C': 10, 'degree': 5, 'gamma': 'auto', 'kerne...  0.613576
# 47  {'C': 10, 'degree': 5, 'gamma': 'auto', 'kerne...  0.626996
# 48  {'C': 10, 'degree': 7, 'gamma': 'scale', 'kern...  0.632653
# 49  {'C': 10, 'degree': 7, 'gamma': 'scale', 'kern...  0.632986
# 50  {'C': 10, 'degree': 7, 'gamma': 'scale', 'kern...  0.626996
# 51  {'C': 10, 'degree': 7, 'gamma': 'auto', 'kerne...  0.633762
# 52  {'C': 10, 'degree': 7, 'gamma': 'auto', 'kerne...  0.583629
# 53  {'C': 10, 'degree': 7, 'gamma': 'auto', 'kerne...  0.626996
# 54  {'C': 100, 'degree': 3, 'gamma': 'scale', 'ker...  0.633873
# 55  {'C': 100, 'degree': 3, 'gamma': 'scale', 'ker...  0.636646
# 56  {'C': 100, 'degree': 3, 'gamma': 'scale', 'ker...  0.626886
# 57  {'C': 100, 'degree': 3, 'gamma': 'auto', 'kern...  0.633651
# 58  {'C': 100, 'degree': 3, 'gamma': 'auto', 'kern...  0.634982
# 59  {'C': 100, 'degree': 3, 'gamma': 'auto', 'kern...  0.626886
# 60  {'C': 100, 'degree': 5, 'gamma': 'scale', 'ker...  0.633873
# 61  {'C': 100, 'degree': 5, 'gamma': 'scale', 'ker...  0.633762
# 48  [0.7246054414291321, 0.5004963869558764, 0.612...
# 49  [0.725829931606834, 0.49301909813396066, 0.613...
# 50  [0.7250214239848297, 0.5249362775790458, 0.574...
# 51  [0.7248800692302102, 0.504550805633993, 0.6135...
# 52  [0.7097923840417264, 0.5352740276478478, 0.362...
# 53  [0.7250214239848297, 0.5249362775790458, 0.574...
# 54  [0.7254969284581927, 0.498900217089148, 0.6143...
# 55  [0.7242703892185836, 0.5117812053015863, 0.620...
# 56  [0.7249339828618525, 0.5246801883993155, 0.574...
# 57  [0.7253845838127168, 0.49901357210403297, 0.61...
# 58  [0.7240743510570153, 0.5092020594411933, 0.617...
# 59  [0.7249339828618525, 0.5246801883993155, 0.574...
# 60  [0.7254969284581927, 0.498900217089148, 0.6143...
# 61  [0.7238455664021771, 0.5064426466837577, 0.612...
# 62  [0.7249339828618525, 0.5246801883993155, 0.574...
# 63  [0.7253845838127168, 0.49901357210403297, 0.61...
# 64  [0.7249612651126922, 0.5015330178784003, 0.607...
# 65  [0.7249339828618525, 0.5246801883993155, 0.574...
# 66  [0.7254969284581927, 0.498900217089148, 0.6143...
# 67  [0.7244210834746657, 0.4921099301302215, 0.612...
# 68  [0.7249339828618525, 0.5246801883993155, 0.574...
# 69  [0.7253845838127168, 0.49901357210403297, 0.61...
# 70  [0.7158557127221069, 0.5317214500372354, 0.449...
# 71  [0.7249339828618525, 0.5246801883993155, 0.574...

# %%
cl_svm
# Out:
# array([-1,  0,  1])

# %%
params_rf = {'n_estimators' : (50, 100, 150),
            'criterion' : ('entropy', 'gini'),
            'max_features' : (None, 'sqrt')}
rf = RandomForestClassifier()
rf_results, cl_rf = test_model(rf, params_rf, X_train, y_train, 4)
# Out:
# Testing {'criterion': 'entropy', 'max_features': None, 'n_estimators': 50}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'entropy', 'max_features': None, 'n_estimators': 100}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'entropy', 'max_features': None, 'n_estimators': 150}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'entropy', 'max_features': 'sqrt', 'n_estimators': 50}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'entropy', 'max_features': 'sqrt', 'n_estimators': 100}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'entropy', 'max_features': 'sqrt', 'n_estimators': 150}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': None, 'n_estimators': 50}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': None, 'n_estimators': 100}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': None, 'n_estimators': 150}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 50}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 100}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 150}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4

# %%
rf_results
# Out:
#                                            Parameters  Accuracy  \
# 0   {'criterion': 'entropy', 'max_features': None,...  0.564774
# 1   {'criterion': 'entropy', 'max_features': None,...  0.568101
# 2   {'criterion': 'entropy', 'max_features': None,...  0.568323
# 3   {'criterion': 'entropy', 'max_features': 'sqrt...  0.570985
# 4   {'criterion': 'entropy', 'max_features': 'sqrt...  0.571872
# 5   {'criterion': 'entropy', 'max_features': 'sqrt...  0.569321
# 6   {'criterion': 'gini', 'max_features': None, 'n...  0.565883
# 7   {'criterion': 'gini', 'max_features': None, 'n...  0.565994
# 8   {'criterion': 'gini', 'max_features': None, 'n...  0.566881
# 9   {'criterion': 'gini', 'max_features': 'sqrt', ...  0.570763
# 10  {'criterion': 'gini', 'max_features': 'sqrt', ...  0.568767
# 11  {'criterion': 'gini', 'max_features': 'sqrt', ...  0.571318
#
#                                             Precision  \
# 0   [0.6324966919692259, 0.47248353065442894, 0.54...
# 1   [0.6351283062276725, 0.4771228613920509, 0.548...
# 2   [0.6358951130894158, 0.4798927944357187, 0.541...
# 3   [0.6342234164043281, 0.48318268250169427, 0.55...
# 4   [0.6372735740130554, 0.482893036084588, 0.5515...
# 5   [0.6352048085737477, 0.4812966927439434, 0.547...
# 6   [0.6301613045364894, 0.47908281866939484, 0.54...
# 7   [0.6338134571336904, 0.47279356658437893, 0.54...
# 8   [0.6329185520361991, 0.4779620953923276, 0.543...
# 9   [0.6382300418686259, 0.48181803021463576, 0.54...
# 10  [0.6342845987991255, 0.4779298266829521, 0.551...
# 11  [0.6367701094291844, 0.4821537130190209, 0.550...
#
#                                                Recall  \
# 0   [0.6976670504534285, 0.4351762411918952, 0.503...
# 1   [0.6947298225837697, 0.4358546821081476, 0.521...
# 2   [0.7014332577566729, 0.43348595425152536, 0.51...
# 3   [0.7063973669468316, 0.4369062329891243, 0.510...
# 4   [0.7031613448528341, 0.4417067636500517, 0.513...
# 5   [0.699219978365538, 0.44065701969698073, 0.511...
# 6   [0.7008219240399354, 0.4289895925259583, 0.509...
# 7   [0.7008102696319793, 0.43062891740044473, 0.50...
# 8   [0.6998760898213647, 0.4320477903434402, 0.511...
# 9   [0.7023039869161782, 0.44131875848219704, 0.51...
# 10  [0.6971998740644114, 0.43957349799033985, 0.51...
# 11  [0.7032984501916638, 0.44127005305453115, 0.51...
#
#                                                    F1
# 0   [0.6631561779384035, 0.4529236446220571, 0.523...
# 1   [0.663374277883136, 0.4554751359226386, 0.5339...
# 2   [0.6668267095203396, 0.4554304410786146, 0.526...
# 3   [0.668249678304811, 0.45878288537136014, 0.529...
# 4   [0.6683870659965626, 0.4613443786917838, 0.531...
# 5   [0.6655455141578948, 0.46001672440069824, 0.52...
# 6   [0.663472674544726, 0.4526032237736892, 0.5250...
# 7   [0.6654993298234069, 0.45070250013181967, 0.52...
# 8   [0.6645022113285434, 0.45380636760775217, 0.52...
# 9   [0.6686053801266961, 0.46065366895776794, 0.52...
# 10  [0.664095583318954, 0.4578721838618453, 0.5319...
# 11  [0.6683060811355086, 0.46076045842730184, 0.53...

# %%
cl_rf
# Out:
# array([-1,  0,  1])

# %%
params_knn = {'n_neighbors' : (1, 3, 5, 7, 9),
             'metric' : ('minkowski', 'euclidean', 'manhattan', 'cosine')}
knn = KNeighborsClassifier()
knn_results, cl_knn = test_model(knn, params_knn, X_train, y_train, 4)
# Out:
# Testing {'metric': 'minkowski', 'n_neighbors': 1}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'minkowski', 'n_neighbors': 3}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'minkowski', 'n_neighbors': 5}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'minkowski', 'n_neighbors': 7}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'minkowski', 'n_neighbors': 9}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'euclidean', 'n_neighbors': 1}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'euclidean', 'n_neighbors': 3}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'euclidean', 'n_neighbors': 5}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'euclidean', 'n_neighbors': 7}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'euclidean', 'n_neighbors': 9}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'manhattan', 'n_neighbors': 1}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'manhattan', 'n_neighbors': 3}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'manhattan', 'n_neighbors': 5}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'manhattan', 'n_neighbors': 7}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'manhattan', 'n_neighbors': 9}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'cosine', 'n_neighbors': 1}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 
# 4   [0.7746502523371508, 0.4205637191191942, 0.542...
# 5   [0.6282450237158113, 0.4265040128634734, 0.498...
# 6   [0.7294948843739112, 0.39577564955399536, 0.49...
# 7   [0.7589815827769899, 0.4267174545290324, 0.493...
# 8   [0.7623427598128775, 0.4316031375903987, 0.527...
# 9   [0.7746502523371508, 0.4205637191191942, 0.542...
# 10  [0.6276894045297058, 0.4238052572577094, 0.493...
# 11  [0.7315713272896767, 0.3988453715883938, 0.493...
# 12  [0.7574269914287398, 0.4236559880426066, 0.494...
# 13  [0.7634143869014922, 0.4308810909816245, 0.524...
# 14  [0.7728878266638988, 0.426710439176203, 0.5420...
# 15  [0.6295772949779783, 0.4369373415234911, 0.501...
# 16  [0.7157121521962017, 0.4091753925545822, 0.493...
# 17  [0.7563316248643218, 0.4260480596455842, 0.487...
# 18  [0.759906911112879, 0.4350618008505765, 0.5252...
# 19  [0.7772220176927747, 0.41475809077908654, 0.54...
#
#                                                    F1
# 0   [0.6231231251209672, 0.43420668397385975, 0.49...
# 1   [0.6584329801287998, 0.4343213893152641, 0.530...
# 2   [0.6845915821544277, 0.45790311482753737, 0.54...
# 3   [0.6963325223337133, 0.46686662725216194, 0.56...
# 4   [0.7014156976271575, 0.463965474449575, 0.5761...
# 5   [0.6231231251209672, 0.43420668397385975, 0.49...
# 6   [0.6584329801287998, 0.4343213893152641, 0.530...
# 7   [0.6845915821544277, 0.45790311482753737, 0.54...
# 8   [0.6963325223337133, 0.46686662725216194, 0.56...
# 9   [0.7014156976271575, 0.463965474449575, 0.5761...
# 10  [0.6218834498206162, 0.43126651455847387, 0.48...
# 11  [0.660224895753978, 0.4380702167953646, 0.5308...
# 12  [0.6833883637354075, 0.4560291743987912, 0.546...
# 13  [0.6971169929752674, 0.4651216355639053, 0.562...
# 14  [0.7016147298100093, 0.4687521800021873, 0.575...
# 15  [0.6243736012624489, 0.4417150891980513, 0.500...
# 16  [0.6522042562539037, 0.4422072105203184, 0.531...
# 17  [0.6824221179592691, 0.45599210134592016, 0.54...
# 18  [0.6956085430212309, 0.4690906959322837, 0.561...
# 19  [0.7013804147569069, 0.4619185472401965, 0.572...

# %%
cl_knn
# Out:
# array([-1,  0,  1])

# %%
params_lr = {'penalty' : ('l1', 'l2', 'elasticnet', None),
            'C' : (0.1, 1, 10, 100),
            'solver' : ('lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga'),
            'max_iter' : [500]}

lr = LogisticRegression()
lr_results, cl_lr = test_model(lr, params_lr, X_train, y_train, 4)
# Out:
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'sag'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': None, 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': None, 'solver': 'sag'}
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 1 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 2 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 3 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': None, 'solver': 'saga'}
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 1 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 2 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 3 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'sag'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': None, 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': None, 'solver': 'sag'}
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 	Fold 1 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 	Fold 2 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 	Fold 3 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': None, 'solver': 'saga'}
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 	Fold 1 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 	Fold 2 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 	Fold 3 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l2', 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l2', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l2', 'solver': 'sag'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l2', 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': None, 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# Testing {'C': 10, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': None, 'solver': 'sag'}
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 1 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 2 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 3 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': None, 'solver': 'saga'}
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 1 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 2 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 3 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'saga'}
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 	Fold 1 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 	Fold 2 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 	Fold 3 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'sag'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'sag'}
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 1 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 2 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 3 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'saga'}
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 1 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 2 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 3 of 4
# 	Fold 4 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %%
lr_results
# Out:
#                                            Parameters  Accuracy  \
# 0   {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', '...  0.627551
# 1   {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', '...  0.627107
# 2   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.627107
# 3   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.627551
# 4   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.627107
# 5   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.627551
# 6   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.627107
# 7   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.627107
# 8   {'C': 0.1, 'max_iter': 500, 'penalty': None, '...  0.626996
# 9   {'C': 0.1, 'max_iter': 500, 'penalty': None, '...  0.627995
# 10  {'C': 0.1, 'max_iter': 500, 'penalty': None, '...  0.628771
# 11  {'C': 0.1, 'max_iter': 500, 'penalty': None, '...  0.627329
# 12  {'C': 0.1, 'max_iter': 500, 'penalty': None, '...  0.627218
# 13  {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'so...  0.628217
# 14  {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'so...  0.627218
# 15  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.626886
# 16  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.627995
# 17  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.626886
# 18  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.627995
# 19  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.626886
# 20  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.626886
# 21  {'C': 1, 'max_iter': 500, 'penalty': None, 'so...  0.626996
# 22  {'C': 1, 'max_iter': 500, 'penalty': None, 'so...  0.627995
# 23  {'C': 1, 'max_iter': 500, 'penalty': None, 'so...  0.628771
# 24  {'C': 1, 'max_iter': 500, 'penalty': None, 'so...  0.627329
# 25  {'C': 1, 'max_iter': 500, 'penalty': None, 'so...  0.627218
# 26  {'C': 10, 'max_iter': 500, 'penalty': 'l1', 's...  0.628106
# 27  {'C': 10, 'max_iter': 500, 'penalty': 'l1', 's...  0.626996
# 28  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.626996
# 29  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.628106
# 30  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.626996
# 31  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.628106
# 32  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.626996
# 33  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.626996
# 34  {'C': 10, 'max_iter': 500, 'penalty': None, 's...  0.626996
# 35  {'C': 10, 'max_iter': 500, 'penalty': None, 's...  0.627995
# 36  {'C': 10, 'max_iter': 500, 'penalty': None, 's...  0.628771
# 37  {'C': 10, 'max_iter': 500, 'penalty': None, 's...  0.627329
# 38  {'C': 10, 'max_iter': 500, 'penalty': None, 's...  0.627218
# 39  {'C': 100, 'max_iter': 500, 'penalty': 'l1', '...  0.628106
# 40  {'C': 100, 'max_iter': 500, 'penalty': 'l1', '...  0.627107
# 41  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.626996
# 42  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.628106
# 43  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.627107
# 44  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.627995
# 45  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.627107
# 46  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.627107
# 47  {'C': 100, 'max_iter': 500, 'penalty': None, '...  0.626996
# 48  {'C': 100, 'max_iter': 500, 'penalty': None, '...  0.627995
# 49  {'C': 100, 'max_iter': 500, 'penalty': None, '...  0.628771
# 50  {'C': 100, 'max_iter': 500, 'penalty': None, '...  0.627329
# 51  {'C': 100, 'max_iter': 500, 'penalty': None, '...  0.627218
#
#                                             Precision  \
# 0   [0.6750696153833136, 0.5275574181824365, 0.663...
# 1   [0.6783524858802982, 0.5223507754806074, 0.668...
# 2   [0.6797475936281707, 0.5225407480339946, 0.664...
# 3   [0.6755981405901934, 0.5272470477449311, 0.664...
# 4   [0.6797475936281707, 0.5225407480339946, 0.664...
