# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, ParameterGrid
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from transformers import AutoModelForSequenceClassification
from transformers import TrainingArguments
import numpy as np
import evaluate
from transformers import TrainingArguments, Trainer
from transformers import AutoTokenizer
from datasets import Dataset
from transformers import TextClassificationPipeline

# %%
dfo = pd.read_csv('data/obama_cleaned.csv')
dfo = dfo.rename(columns={'tweets' : 'text', 'class' : 'label'})
dfr = pd.read_csv('data/romney_cleaned.csv')
dfr = dfr.rename(columns={'tweets' : 'text', 'class' : 'label'})
df = pd.concat([dfo, dfr], ignore_index = True)
df.info()
pd.set_option('display.max_rows', None)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11271 entries, 0 to 11270
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    11271 non-null  object
#  1   label   11271 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 176.2+ KB

# %%
df = df.astype({'text' : 'string'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11271 entries, 0 to 11270
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    11271 non-null  string
#  1   label   11271 non-null  int64
# dtypes: int64(1), string(1)
# memory usage: 176.2 KB

# %% [markdown]
# # Pre-trained model: BERTweet

# %% [markdown]
# Fine-tuning using our data:

# %%
X = dfo['text']
y = dfo['label'].map({1 : 2, 0 : 1, -1 : 0})
X, X_test, y, y_test = train_test_split(X, y, test_size = 0.2)
X_train, X_eval, y_train, y_eval = train_test_split(X, y, test_size = 0.25)


traindf = pd.concat([X_train,y_train], axis = 1)

evaldf = pd.concat([X_eval,y_eval], axis = 1)

testdf = pd.concat([X_test,y_test], axis = 1)

# %%
train = Dataset.from_pandas(traindf, split = 'train')
val = Dataset.from_pandas(evaldf, split = 'eval')
test = Dataset.from_pandas(testdf, split = 'test')

# %%
tokenizer = AutoTokenizer.from_pretrained("finiteautomata/bertweet-base-sentiment-analysis")


def tokenize_function(examples):
    return tokenizer(examples["text"], padding="max_length", truncation=True)
    

tokenized_train = train.map(tokenize_function, batched=True)
tokenized_eval = val.map(tokenize_function, batched=True)
tokenized_test = test.map(tokenize_function, batched=True)
# Out:
# Map:   0%|          | 0/3374 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1125 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1125 [00:00<?, ? examples/s]

# %%
model = AutoModelForSequenceClassification.from_pretrained("finiteautomata/bertweet-base-sentiment-analysis", num_labels=3)
metric = evaluate.load("accuracy")

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

training_args = TrainingArguments(output_dir="checkpoints/test_trainer_unique", evaluation_strategy="epoch", num_train_epochs=3)
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_eval,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
#     <div>
#
#       <progress value='1266' max='1266' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1266/1266 08:10, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>0.766345</td>
#       <td>0.679111</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.774800</td>
#       <td>0.912529</td>
#       <td>0.695111</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.425700</td>
#       <td>1.171285</td>
#       <td>0.711111</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=1266, training_loss=0.5343863139220324, metrics={'train_runtime': 491.4506, 'train_samples_per_second': 20.596, 'train_steps_per_second': 2.576, 'total_flos': 665808503560704.0, 'train_loss': 0.5343863139220324, 'epoch': 3.0})

# %%
trainer.save_model('models/model_unique')

# %% [markdown]
# # Load from checkpoints

# %%
model = AutoModelForSequenceClassification.from_pretrained("checkpoints/test_trainer_unique", num_labels=3)
metric = evaluate.load("accuracy")

def compute_metrics(eval_pred):
    logits, labels = eval_pred
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

training_args = TrainingArguments(output_dir="test_trainer_unique", evaluation_strategy="epoch", num_train_epochs=5)
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train,
    eval_dataset=tokenized_eval,
    compute_metrics=compute_metrics,
)

trainer.train()

# %% [markdown]
# # Load finetuned models

# %%
model = AutoModelForSequenceClassification.from_pretrained('models/model_unique')

# %%
pipe = TextClassificationPipeline(model=model, tokenizer=tokenizer)

# %%
pos = list()
neg = list()
neu = list()
pred = pd.DataFrame()
for t in testdf['text']:
    prediction = pipe(t, top_k=None)
    for l in prediction:
        if l['label'] == 'POS':
            pos.append(l['score'])
        elif l['label'] == 'NEG':
            neg.append(l['score'])
        else: 
            neu.append(l['score'])
            
pred['pos'] = pos
pred['neg'] = neg
pred['neu'] = neu

# %%
pred['class'] = list(y_test.map({0 : -1, 1 : 0, 2 : 1}))

# %% [markdown]
# # Predict label using maximum probability

# %%
def pred_label(df):
    preds = list()
    for idx, row in df.iterrows():
        if row['pos'] >= row['neu'] and row['pos'] >= row['neg']:
            preds.append(1)
        elif row['neg'] >= row['neu'] and row['neg'] > row['pos']:
            preds.append(-1)
        elif row['neu'] > row['pos'] and row['neu'] > row['neg']:
            preds.append(0)
    df['pred'] = preds
    acc = accuracy_score(df['class'], df['pred'])
    prec = precision_score(df['class'], df['pred'], average = None, zero_division = np.nan)
    rec = recall_score(df['class'], df['pred'], average = None)
    f1 = f1_score(df['class'], df['pred'], average = None)
    print("Accuracy:", acc)
    print("Precision:", prec)
    print("Recall:", rec)
    print("F1:", f1)
    return df

# %%
predicted_labels = pred_label(pred)
# Out:
# Accuracy: 0.72
# Precision: [0.72817955 0.66240409 0.77777778]
# Recall: [0.74489796 0.66925065 0.74855491]
# F1: [0.73644388 0.66580977 0.7628866 ]

# %%
predicted_labels['pred'].value_counts()
# Out:
# -1    401
#  0    391
#  1    333
# Name: pred, dtype: int64

# %% [markdown]
# # Predict label using ML models

# %%
def test_model(model, parameters, X, y, n_splits):
    kf = KFold(n_splits=n_splits, shuffle=True, random_state = 27)
    avg_accuracies = list()
    avg_precisions = list()
    avg_recalls = list()
    avg_f1s = list()
    confs = list()
    for conf in ParameterGrid(parameters):
        print('Testing', conf)
        accuracies = list()
        precisions = list()
        recalls = list()
        f1s = list()
        i = 1
        for train_index, test_index in kf.split(X):
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train, y_test = y.iloc[train_index], y.iloc[test_index]
            try:
                model.set_params(**conf)
                model.fit(X_train, y_train)
            except:
                print('Skipped', conf)
                break
            print('\tFold', i, 'of', n_splits)
            y_pred = model.predict(X_test)
            accuracies.append(accuracy_score(y_test, y_pred))
            precisions.append(precision_score(y_test, y_pred, average=None, zero_division = np.nan))
            recalls.append(recall_score(y_test, y_pred, average=None, zero_division = np.nan))
            f1s.append(f1_score(y_test, y_pred, average=None, zero_division = np.nan))
            if i == 1:
                confs.append(conf)
            i = i + 1
            
    
        if len(accuracies) != 0:  
            avg_accuracies.append(sum(accuracies)/len(accuracies))
            avg_precisions.append((sum(precisions)/len(precisions)) if len(precisions) > 0 else np.nan)
            avg_recalls.append(sum(recalls)/len(recalls) if len(recalls) > 0 else np.nan)
            avg_f1s.append(sum(f1s)/len(f1s) if len(f1s) > 0 else np.nan)
        
    results = {'Parameters' : confs,
              'Accuracy' : avg_accuracies,
              'Precision' : avg_precisions,
              'Recall' : avg_recalls,
              'F1' : avg_f1s}
    
    return pd.DataFrame.from_dict(results)

# %%
X = predicted_labels[['pos', 'neg', 'neu']]
y = predicted_labels['class']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
params_svm = {'C' : (0.1, 1, 10, 100),
             'kernel' : ('rbf', 'poly', 'linear'),
             'degree' : (3, 5, 7),
             'gamma' : ('scale', 'auto')}
svm = SVC()
svm_results = test_model(svm, params_svm, X_train, y_train, 4)
# Out:
# Testing {'C': 0.1, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 3, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 5, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 5, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 5, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 5, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 7, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 7, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 7, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 7, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 7, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'degree': 7, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 3, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 5, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 5, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 5, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 5, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 7, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 7, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 7, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 7, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 7, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'degree': 7, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 3, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 5, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 5, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 5, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 5, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 7, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 7, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 7, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 7, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 7, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'degree': 7, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 3, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 3, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 3, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 3, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 3, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 3, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 5, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 5, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 5, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 5, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 5, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 5, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 7, 'gamma': 'scale', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 7, 'gamma': 'scale', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 7, 'gamma': 'scale', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 7, 'gamma': 'auto', 'kernel': 'rbf'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 7, 'gamma': 'auto', 'kernel': 'poly'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'degree': 7, 'gamma': 'auto', 'kernel': 'linear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4

# %%
svm_results
# Out:
#                                            Parameters  Accuracy  \
# 0   {'C': 0.1, 'degree': 3, 'gamma': 'scale', 'ker...  0.714444
# 1   {'C': 0.1, 'degree': 3, 'gamma': 'scale', 'ker...  0.715556
# 2   {'C': 0.1, 'degree': 3, 'gamma': 'scale', 'ker...  0.716667
# 3   {'C': 0.1, 'degree': 3, 'gamma': 'auto', 'kern...  0.715556
# 4   {'C': 0.1, 'degree': 3, 'gamma': 'auto', 'kern...  0.326667
# 5   {'C': 0.1, 'degree': 3, 'gamma': 'auto', 'kern...  0.716667
# 6   {'C': 0.1, 'degree': 5, 'gamma': 'scale', 'ker...  0.714444
# 7   {'C': 0.1, 'degree': 5, 'gamma': 'scale', 'ker...  0.716667
# 8   {'C': 0.1, 'degree': 5, 'gamma': 'scale', 'ker...  0.716667
# 9   {'C': 0.1, 'degree': 5, 'gamma': 'auto', 'kern...  0.715556
# 10  {'C': 0.1, 'degree': 5, 'gamma': 'auto', 'kern...  0.326667
# 11  {'C': 0.1, 'degree': 5, 'gamma': 'auto', 'kern...  0.716667
# 12  {'C': 0.1, 'degree': 7, 'gamma': 'scale', 'ker...  0.714444
# 13  {'C': 0.1, 'degree': 7, 'gamma': 'scale', 'ker...  0.716667
# 14  {'C': 0.1, 'degree': 7, 'gamma': 'scale', 'ker...  0.716667
# 15  {'C': 0.1, 'degree': 7, 'gamma': 'auto', 'kern...  0.715556
# 16  {'C': 0.1, 'degree': 7, 'gamma': 'auto', 'kern...  0.326667
# 17  {'C': 0.1, 'degree': 7, 'gamma': 'auto', 'kern...  0.716667
# 18  {'C': 1, 'degree': 3, 'gamma': 'scale', 'kerne...  0.710000
# 19  {'C': 1, 'degree': 3, 'gamma': 'scale', 'kerne...  0.712222
# 20  {'C': 1, 'degree': 3, 'gamma': 'scale', 'kerne...  0.716667
# 21  {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel...  0.715556
# 22  {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel...  0.713333
# 23  {'C': 1, 'degree': 3, 'gamma': 'auto', 'kernel...  0.716667
# 24  {'C': 1, 'degree': 5, 'gamma': 'scale', 'kerne...  0.710000
# 25  {'C': 1, 'degree': 5, 'gamma': 'scale', 'kerne...  0.708889
# 26  {'C': 1, 'degree': 5, 'gamma': 'scale', 'kerne...  0.716667
# 27  {'C': 1, 'degree': 5, 'gamma': 'auto', 'kernel...  0.715556
# 28  {'C': 1, 'degree': 5, 'gamma': 'auto', 'kernel...  0.326667
# 29  {'C': 1, 'degree': 5, 'gamma': 'auto', 'kernel...  0.716667
# 30  {'C': 1, 'degree': 7, 'gamma': 'scale', 'kerne...  0.710000
# 31  {'C': 1, 'degree': 7, 'gamma': 'scale', 'kerne...  0.710000
# 32  {'C': 1, 'degree': 7, 'gamma': 'scale', 'kerne...  0.716667
# 33  {'C': 1, 'degree': 7, 'gamma': 'auto', 'kernel...  0.715556
# 34  {'C': 1, 'degree': 7, 'gamma': 'auto', 'kernel...  0.326667
# 35  {'C': 1, 'degree': 7, 'gamma': 'auto', 'kernel...  0.716667
# 36  {'C': 10, 'degree': 3, 'gamma': 'scale', 'kern...  0.710000
# 37  {'C': 10, 'degree': 3, 'gamma': 'scale', 'kern...  0.712222
# 38  {'C': 10, 'degree': 3, 'gamma': 'scale', 'kern...  0.716667
# 39  {'C': 10, 'degree': 3, 'gamma': 'auto', 'kerne...  0.710000
# 40  {'C': 10, 'degree': 3, 'gamma': 'auto', 'kerne...  0.717778
# 41  {'C': 10, 'degree': 3, 'gamma': 'auto', 'kerne...  0.716667
# 42  {'C': 10, 'degree': 5, 'gamma': 'scale', 'kern...  0.710000
# 43  {'C': 10, 'degree': 5, 'gamma': 'scale', 'kern...  0.712222
# 44  {'C': 10, 'degree': 5, 'gamma': 'scale', 'kern...  0.716667
# 45  {'C': 10, 'degree': 5, 'gamma': 'auto', 'kerne...  0.710000
# 46  {'C': 10, 'degree': 5, 'gamma': 'auto', 'kerne...  0.717778
# 47  {'C': 10, 'degree': 5, 'gamma': 'auto', 'kerne...  0.716667
# 48  {'C': 10, 'degree': 7, 'gamma': 'scale', 'kern...  0.710000
# 49  {'C': 10, 'degree': 7, 'gamma': 'scale', 'kern...  0.716667
# 50  {'C': 10, 'degree': 7, 'gamma': 'scale', 'kern...  0.716667
# 51  {'C': 10, 'degree': 7, 'gamma': 'auto', 'kerne...  0.710000
# 52  {'C': 10, 'degree': 7, 'gamma': 'auto', 'kerne...  0.326667
# 53  {'C': 10, 'degree': 7, 'gamma': 'auto', 'kerne...  0.716667
# 54  {'C': 100, 'degree': 3, 'gamma': 'scale', 'ker...  0.715556
# 55  {'C': 100, 'degree': 3, 'gamma': 'scale', 'ker...  0.714444
# 56  {'C': 100, 'degree': 3, 'gamma': 'scale', 'ker...  0.716667
# 57  {'C': 100, 'degree': 3, 'gamma': 'auto', 'kern...  0.708889
# 58  {'C': 100, 'degree': 3, 'gamma': 'auto', 'kern...  0.707778
# 59  {'C': 100, 'degree': 3, 'gamma': 'auto', 'kern...  0.716667
# 60  {'C': 100, 'degree': 5, 'gamma': 'scale', 'ker...  0.715556
# 61  {'C': 100, 'degree': 5, 'gamma': 'scale', 'ker...  0.714444
# 62  {'C': 100, 'degree': 5, 'gamma': 'scale', 'ker...  0.716667
# 63  {'C': 100, 'degree': 5, 'gamma': 'auto', 'kern...  0.708889
# 64  {'C': 100, 'degree': 5, 'gamma': 'auto', 'kern...  0.720000
# 65  {'C': 100, 'degree': 5, 'gamma': 'auto', 'kern...  0.716667
# 66  {'C': 100, 'degree': 7, 'gamma': 'scale', 'ker...  0.715556
# 67  {'C': 100, 'degree': 7, 'gamma': 'scale', 'ker...  0.716667
# 68  {'C': 100, 'degree': 7, 'gamma': 'scale', 'ker...  0.716667
# 69  {'C': 100, 'degree': 7, 'gamma': 'auto', 'kern...  0.708889
# 70  {'C': 100, 'degree': 7, 'gamma': 'auto', 'kern...  0.716667
# 71  {'C': 100, 'degree': 7, 'gamma': 'auto', 'kern...  0.716667
#
#                                             Precision  \
# 0   [0.7179585058661145, 0.6733597145453516, 0.765...
# 1   [0.7346750149075731, 0.6521363162316879, 0.789...
# 2   [0.7180053547523427, 0.6805039416262875, 0.763...
# 3   [0.7203929539295393, 0.6775123420171967, 0.760...
# 4                                     [nan, nan, nan]
# 5   [0.7180053547523427, 0.6805039416262875, 0.763...

# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'entropy', 'max_features': None, 'n_estimators': 150}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'entropy', 'max_features': 'sqrt', 'n_estimators': 50}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'entropy', 'max_features': 'sqrt', 'n_estimators': 100}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'entropy', 'max_features': 'sqrt', 'n_estimators': 150}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': None, 'n_estimators': 50}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': None, 'n_estimators': 100}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': None, 'n_estimators': 150}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 50}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 100}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 150}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4

# %%
rf_results
# Out:
#                                            Parameters  Accuracy  \
# 0   {'criterion': 'entropy', 'max_features': None,...  0.661111
# 1   {'criterion': 'entropy', 'max_features': None,...  0.667778
# 2   {'criterion': 'entropy', 'max_features': None,...  0.662222
# 3   {'criterion': 'entropy', 'max_features': 'sqrt...  0.672222
# 4   {'criterion': 'entropy', 'max_features': 'sqrt...  0.666667
# 5   {'criterion': 'entropy', 'max_features': 'sqrt...  0.660000
# 6   {'criterion': 'gini', 'max_features': None, 'n...  0.666667
# 7   {'criterion': 'gini', 'max_features': None, 'n...  0.662222
# 8   {'criterion': 'gini', 'max_features': None, 'n...  0.657778
# 9   {'criterion': 'gini', 'max_features': 'sqrt', ...  0.660000
# 10  {'criterion': 'gini', 'max_features': 'sqrt', ...  0.665556
# 11  {'criterion': 'gini', 'max_features': 'sqrt', ...  0.676667
#
#                                             Precision  \
# 0   [0.6838281886783727, 0.6165138265490377, 0.693...
# 1   [0.6910624098124097, 0.6222856401451216, 0.700...
# 2   [0.679763515886265, 0.6121859215492871, 0.7088...
# 3   [0.6879324702854114, 0.6326623305839177, 0.710...
# 4   [0.6855041311113529, 0.6214546523855244, 0.703...
# 5   [0.6743567406882431, 0.6113338728633043, 0.711...
# 6   [0.681336781233461, 0.6148702249406395, 0.7206...
# 7   [0.6840277777777778, 0.6099355128276682, 0.699...
# 8   [0.6902934419381788, 0.6082963237587594, 0.686...
# 9   [0.6614749189149344, 0.6163081210161594, 0.731...
# 10  [0.6821461670859261, 0.6205973205442982, 0.715...
# 11  [0.6981670166705556, 0.6278655361666198, 0.722...
#
#                                                Recall  \
# 0   [0.7284640846567952, 0.589307933057933, 0.6745...
# 1   [0.7214786811739418, 0.5982365044865046, 0.692...
# 2   [0.7198244936620503, 0.5912471537471538, 0.682...
# 3   [0.7362782607056539, 0.6114035176535175, 0.675...
# 4   [0.7266691274487801, 0.6048022923022922, 0.674...
# 5   [0.7106123621682214, 0.5983504108504109, 0.678...
# 6   [0.7266849804227186, 0.6109976734976735, 0.667...
# 7   [0.7190210284213707, 0.5901128713628714, 0.685...
# 8   [0.7120261705871299, 0.594452281952282, 0.6749...
# 9   [0.7033801736066319, 0.6137902075402075, 0.671...
# 10  [0.7058378263592029, 0.6133843633843633, 0.685...
# 11  [0.7206468602423024, 0.6259961884961885, 0.689...
#
#                                                    F1
# 0   [0.7040719163946114, 0.6002426536879591, 0.680...
# 1   [0.7041716316921351, 0.6076235736229976, 0.692...
# 2   [0.6976921315102591, 0.5994772067075989, 0.690...
# 3   [0.7105386851985175, 0.6194516457026523, 0.688...
# 4   [0.7043238026918084, 0.610851062610765, 0.6849...
# 5   [0.6913800354757844, 0.6017826920916476, 0.690...
# 6   [0.7024828698222143, 0.6110904963750492, 0.690...
# 7   [0.6990478145621759, 0.5981789890942335, 0.690...
# 8   [0.6992935829116473, 0.5987409565363686, 0.677...
# 9   [0.6803905584500443, 0.610969387755102, 0.6942...
# 10  [0.6924734469594567, 0.6139115599837014, 0.694...
# 11  [0.7079488919041157, 0.623901281377531, 0.7008...

# %%
params_knn = {'n_neighbors' : (1, 3, 5, 7, 9),
             'metric' : ('minkowski', 'euclidean', 'manhattan', 'cosine')}
knn = KNeighborsClassifier()
knn_results = test_model(knn, params_knn, X_train, y_train, 4)
# Out:
# Testing {'metric': 'minkowski', 'n_neighbors': 1}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'minkowski', 'n_neighbors': 3}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'minkowski', 'n_neighbors': 5}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'minkowski', 'n_neighbors': 7}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'minkowski', 'n_neighbors': 9}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'euclidean', 'n_neighbors': 1}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'euclidean', 'n_neighbors': 3}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'euclidean', 'n_neighbors': 5}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'euclidean', 'n_neighbors': 7}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'euclidean', 'n_neighbors': 9}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'manhattan', 'n_neighbors': 1}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'manhattan', 'n_neighbors': 3}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'manhattan', 'n_neighbors': 5}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'manhattan', 'n_neighbors': 7}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'manhattan', 'n_neighbors': 9}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'cosine', 'n_neighbors': 1}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'cosine', 'n_neighbors': 3}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'cosine', 'n_neighbors': 5}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'cosine', 'n_neighbors': 7}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'metric': 'cosine', 'n_neighbors': 9}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4

# %%
knn_results
# Out:
#                                    Parameters  Accuracy  \
# 0   {'metric': 'minkowski', 'n_neighbors': 1}  0.622222
# 1   {'metric': 'minkowski', 'n_neighbors': 3}  0.653333
# 2   {'metric': 'minkowski', 'n_neighbors': 5}  0.681111
# 3   {'metric': 'minkowski', 'n_neighbors': 7}  0.687778
# 4   {'metric': 'minkowski', 'n_neighbors': 9}  0.697778
# 5   {'metric': 'euclidean', 'n_neighbors': 1}  0.622222
# 6   {'metric': 'euclidean', 'n_neighbors': 3}  0.653333
# 7   {'metric': 'euclidean', 'n_neighbors': 5}  0.681111
# 8   {'metric': 'euclidean', 'n_neighbors': 7}  0.687778
# 9   {'metric': 'euclidean', 'n_neighbors': 9}  0.697778
# 10  {'metric': 'manhattan', 'n_neighbors': 1}  0.622222
# 11  {'metric': 'manhattan', 'n_neighbors': 3}  0.652222
# 12  {'metric': 'manhattan', 'n_neighbors': 5}  0.684444
# 13  {'metric': 'manhattan', 'n_neighbors': 7}  0.684444
# 14  {'metric': 'manhattan', 'n_neighbors': 9}  0.697778
# 15     {'metric': 'cosine', 'n_neighbors': 1}  0.618889
# 16     {'metric': 'cosine', 'n_neighbors': 3}  0.655556
# 17     {'metric': 'cosine', 'n_neighbors': 5}  0.686667
# 18     {'metric': 'cosine', 'n_neighbors': 7}  0.696667
# 19     {'metric': 'cosine', 'n_neighbors': 9}  0.697778
#
#                                             Precision  \
# 0   [0.626640518214774, 0.598409029330082, 0.64720...
# 1   [0.6120287766399402, 0.6249589666802245, 0.757...
# 2   [0.6761717223865602, 0.6259078237793224, 0.781...
# 3   [0.6904639481042532, 0.6258954678362573, 0.786...
# 4   [0.6837064559140968, 0.6480453850789961, 0.807...
# 5   [0.626640518214774, 0.598409029330082, 0.64720...
# 6   [0.6120287766399402, 0.6249589666802245, 0.757...
# 7   [0.6761717223865602, 0.6259078237793224, 0.781...
# 8   [0.6904639481042532, 0.6258954678362573, 0.786...
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'sag'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': None, 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Skipped {'C': 0.1, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': None, 'solver': 'sag'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #3. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=9.7129e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=7.13088e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=7.13088e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=7.13088e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #4. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=1.10204e-16): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 4 of 4
# Testing {'C': 0.1, 'max_iter': 500, 'penalty': None, 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'sag'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': None, 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Skipped {'C': 1, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Testing {'C': 1, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': None, 'solver': 'sag'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 1, 'max_iter': 500, 'penalty': None, 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l1', 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l2', 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l2', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l2', 'solver': 'sag'}
# 	Fold 1 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #3. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=9.7129e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=7.13088e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=7.13088e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=7.13088e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #4. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=1.10204e-16): result may not be accurate.
#   warnings.warn(
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'l2', 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': None, 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Skipped {'C': 10, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Testing {'C': 10, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': None, 'solver': 'sag'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 10, 'max_iter': 500, 'penalty': None, 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'lbfgs'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cg'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'newton-cholesky'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'sag'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l1', 'solver': 'saga'}
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #3. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=9.7129e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=7.13088e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=7.13088e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=7.13088e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #4. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=1.10204e-16): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'liblinear'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'sag'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'l2', 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'lbfgs'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'liblinear'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cg'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'newton-cholesky'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'sag'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': 'elasticnet', 'solver': 'saga'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'lbfgs'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Skipped {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'liblinear'}
# Testing {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cg'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'newton-cholesky'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'sag'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# Testing {'C': 100, 'max_iter': 500, 'penalty': None, 'solver': 'saga'}
# 	Fold 1 of 4
# 	Fold 2 of 4
# 	Fold 3 of 4
# 	Fold 4 of 4
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #3. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=9.7129e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=7.13088e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=7.13088e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #1. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=7.13088e-17): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_glm/_newton_solver.py:498: LinAlgWarning: The inner solver of NewtonCholeskySolver stumbled upon a singular or very ill-conditioned Hessian matrix at iteration #4. It will now resort to lbfgs instead.
# Further options are to use another solver or to avoid such situation in the first place. Possible remedies are removing collinear features of X or increasing the penalization strengths.
# The original Linear Algebra message was:
# Ill-conditioned matrix (rcond=1.10204e-16): result may not be accurate.
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(
# /opt/homebrew/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:1193: UserWarning: Setting penalty=None will ignore the C and l1_ratio parameters
#   warnings.warn(

# %%
lr_results
# Out:
#                                            Parameters  Accuracy  \
# 0   {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', '...  0.717778
# 1   {'C': 0.1, 'max_iter': 500, 'penalty': 'l1', '...  0.716667
# 2   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.715556
# 3   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.717778
# 4   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.715556
# 5   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.717778
# 6   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.715556
# 7   {'C': 0.1, 'max_iter': 500, 'penalty': 'l2', '...  0.715556
# 8   {'C': 0.1, 'max_iter': 500, 'penalty': None, '...  0.716667
# 9   {'C': 0.1, 'max_iter': 500, 'penalty': None, '...  0.716667
# 10  {'C': 0.1, 'max_iter': 500, 'penalty': None, '...  0.717778
# 11  {'C': 0.1, 'max_iter': 500, 'penalty': None, '...  0.716667
# 12  {'C': 0.1, 'max_iter': 500, 'penalty': None, '...  0.716667
# 13  {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'so...  0.717778
# 14  {'C': 1, 'max_iter': 500, 'penalty': 'l1', 'so...  0.716667
# 15  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.716667
# 16  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.717778
# 17  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.716667
# 18  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.717778
# 19  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.716667
# 20  {'C': 1, 'max_iter': 500, 'penalty': 'l2', 'so...  0.716667
# 21  {'C': 1, 'max_iter': 500, 'penalty': None, 'so...  0.716667
# 22  {'C': 1, 'max_iter': 500, 'penalty': None, 'so...  0.716667
# 23  {'C': 1, 'max_iter': 500, 'penalty': None, 'so...  0.717778
# 24  {'C': 1, 'max_iter': 500, 'penalty': None, 'so...  0.716667
# 25  {'C': 1, 'max_iter': 500, 'penalty': None, 'so...  0.716667
# 26  {'C': 10, 'max_iter': 500, 'penalty': 'l1', 's...  0.717778
# 27  {'C': 10, 'max_iter': 500, 'penalty': 'l1', 's...  0.716667
# 28  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.716667
# 29  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.717778
# 30  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.716667
# 31  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.717778
# 32  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.716667
# 33  {'C': 10, 'max_iter': 500, 'penalty': 'l2', 's...  0.716667
# 34  {'C': 10, 'max_iter': 500, 'penalty': None, 's...  0.716667
# 35  {'C': 10, 'max_iter': 500, 'penalty': None, 's...  0.716667
# 36  {'C': 10, 'max_iter': 500, 'penalty': None, 's...  0.717778
# 37  {'C': 10, 'max_iter': 500, 'penalty': None, 's...  0.716667
# 38  {'C': 10, 'max_iter': 500, 'penalty': None, 's...  0.716667
# 39  {'C': 100, 'max_iter': 500, 'penalty': 'l1', '...  0.717778
# 40  {'C': 100, 'max_iter': 500, 'penalty': 'l1', '...  0.716667
# 41  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.716667
# 42  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.717778
# 43  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.716667
# 44  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.717778
# 45  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.716667
# 46  {'C': 100, 'max_iter': 500, 'penalty': 'l2', '...  0.716667
# 47  {'C': 100, 'max_iter': 500, 'penalty': None, '...  0.716667
# 48  {'C': 100, 'max_iter': 500, 'penalty': None, '...  0.716667
# 49  {'C': 100, 'max_iter': 500, 'penalty': None, '...  0.717778
# 50  {'C': 100, 'max_iter': 500, 'penalty': None, '...  0.716667
# 51  {'C': 100, 'max_iter': 500, 'penalty': None, '...  0.716667
